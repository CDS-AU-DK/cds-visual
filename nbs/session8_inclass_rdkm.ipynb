# %% [markdown]
# # Introducing CNNS with TensorFlow
#
#
# In this notebook, we're going to see how we can use ```TensorFlow``` to build convolutional neural networks to work with colour image data.

# %% [markdown]
# ## Load libraries

# %%
# data tools
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn

# sklearn tools
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import classification_report

# tf tools
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (Conv2D, 
                                     MaxPooling2D, 
                                     Activation, 
                                     Flatten, 
                                     Dense)
from tensorflow.keras.utils import plot_model
from tensorflow.keras.optimizers import SGD
from tensorflow.keras import backend as K

# %% [markdown]
# __Define plotting function__

# %%
def plot_history(H, epochs):
    plt.figure(figsize=(12,6))
    plt.subplot(1,2,1)
    plt.plot(np.arange(0, epochs), H.history["loss"], label="train_loss")
    plt.plot(np.arange(0, epochs), H.history["val_loss"], label="val_loss", linestyle=":")
    plt.title("Loss curve")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.tight_layout()
    plt.legend()

    plt.subplot(1,2,2)
    plt.plot(np.arange(0, epochs), H.history["accuracy"], label="train_acc")
    plt.plot(np.arange(0, epochs), H.history["val_accuracy"], label="val_acc", linestyle=":")
    plt.title("Accuracy curve")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.tight_layout()
    plt.legend()
    plt.show()

# %% [markdown]
# __Load cifar10 data__

# %% [markdown]
# We first want to load the ```cifar-10``` dataset, normalize the values, and then binarize the labels.

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# %% [markdown]
# **Question:** As an experiment, see what happens if you try to train the model with un-scaled images. Does it affect performance?

# %%
X_train = X_train/255
X_test = X_test/255

# %%
# create one-hot encodings
lb = LabelBinarizer()
y_train = lb.fit_transform(y_train)
y_test = lb.fit_transform(y_test)

# %% [markdown]
# We'll also manually create a list of labels for when we come to print the classification report later.

# %%
# initialize label names for CIFAR-10 dataset
label_names = ["airplane", "automobile", 
              "bird", "cat", 
              "deer", "dog", 
              "frog", "horse", 
              "ship", "truck"]

# %% [markdown]
# ## ShallowNet

# %% [markdown]
# We're going to begin by creating one of the simplest CNN architectures with only a single convolutional layer. This type of architecture is known as the ShallowNet architecture:
# >INPUT => CONV => ReLU => FC

# %%
#initalise model
model = Sequential()

# define CONV => ReLU
model.add(Conv2D(32, 
                (3,3),
                padding = "same",
                input_shape = (32, 32, 3)))
model.add(Activation("relu"))
          
# FC classifier
model.add(Flatten())
model.add(Dense(128))
model.add(Activation("relu"))
model.add(Dense(10))
model.add(Activation("softmax"))

# %% [markdown]
# __Compile model__

# %% [markdown]
# We then compile our model using some of the same arguments we've already seen in different contexts.

# %%
sgd = SGD(learning_rate =.001)
model.compile(loss="categorical_crossentropy",
              optimizer=sgd,
              metrics=["accuracy"])
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.SGD` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.SGD`.

# %% [markdown]
# __Model summary__

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  activation (Activation)     (None, 32, 32, 32)        0
#
#  flatten (Flatten)           (None, 32768)             0
#
#  dense (Dense)               (None, 128)               4194432
#
#  activation_1 (Activation)   (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
#  activation_2 (Activation)   (None, 10)                0
#
# =================================================================
# Total params: 4196618 (16.01 MB)
# Trainable params: 4196618 (16.01 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# __Train model__

# %% [markdown]
# Finally, we train the model on the data and get our predictions.

# %%
H = model.fit(X_train, y_train,
              validation_split=0.1,
              batch_size=32,
              epochs=20,
              verbose=1)
# Out:
# Epoch 1/20
# 1407/1407 [==============================] - 9s 6ms/step - loss: 2.0669 - accuracy: 0.2634 - val_loss: 1.9439 - val_accuracy: 0.3058
# Epoch 2/20
# 1407/1407 [==============================] - 9s 6ms/step - loss: 1.8641 - accuracy: 0.3486 - val_loss: 1.8491 - val_accuracy: 0.3436
# Epoch 3/20
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.7850 - accuracy: 0.3779 - val_loss: 1.8017 - val_accuracy: 0.3556
# Epoch 4/20
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.7280 - accuracy: 0.3967 - val_loss: 1.7378 - val_accuracy: 0.3928
# Epoch 5/20
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.6827 - accuracy: 0.4132 - val_loss: 1.7020 - val_accuracy: 0.4066
# Epoch 6/20
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.6429 - accuracy: 0.4243 - val_loss: 1.6640 - val_accuracy: 0.4200
# Epoch 7/20
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.6091 - accuracy: 0.4384 - val_loss: 1.6113 - val_accuracy: 0.4418
# Epoch 8/20
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.5791 - accuracy: 0.4474 - val_loss: 1.5886 - val_accuracy: 0.4452
# Epoch 9/20
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.5525 - accuracy: 0.4562 - val_loss: 1.6069 - val_accuracy: 0.4362
# Epoch 10/20
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.5278 - accuracy: 0.4664 - val_loss: 1.5771 - val_accuracy: 0.4372
# Epoch 11/20
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.5062 - accuracy: 0.4747 - val_loss: 1.5731 - val_accuracy: 0.4340
# Epoch 12/20
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.4829 - accuracy: 0.4813 - val_loss: 1.5329 - val_accuracy: 0.4618
# Epoch 13/20
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.4635 - accuracy: 0.4874 - val_loss: 1.5026 - val_accuracy: 0.4810
# Epoch 14/20
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.4421 - accuracy: 0.4972 - val_loss: 1.4966 - val_accuracy: 0.4682
# Epoch 15/20
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.4232 - accuracy: 0.5036 - val_loss: 1.4913 - val_accuracy: 0.4778
# Epoch 16/20
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.4032 - accuracy: 0.5101 - val_loss: 1.4639 - val_accuracy: 0.4770
# Epoch 17/20
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.3856 - accuracy: 0.5151 - val_loss: 1.4473 - val_accuracy: 0.4886
# Epoch 18/20
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.3661 - accuracy: 0.5218 - val_loss: 1.4079 - val_accuracy: 0.5008
# Epoch 19/20
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.3490 - accuracy: 0.5288 - val_loss: 1.4227 - val_accuracy: 0.4974
# Epoch 20/20
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.3319 - accuracy: 0.5323 - val_loss: 1.4080 - val_accuracy: 0.4948

# %% [markdown]
# __Evaluate model__

# %%
predictions = model.predict(X_test, batch_size=32)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
print(classification_report(y_test.argmax(axis=1),
                            predictions.argmax(axis=1),
                            target_names=label_names))
# Out:
#               precision    recall  f1-score   support
#
#     airplane       0.64      0.45      0.53      1000
#   automobile       0.64      0.62      0.63      1000
#         bird       0.45      0.23      0.31      1000
#          cat       0.39      0.33      0.36      1000
#         deer       0.32      0.61      0.42      1000
#          dog       0.60      0.17      0.27      1000
#         frog       0.45      0.71      0.55      1000
#        horse       0.60      0.53      0.56      1000
#         ship       0.51      0.76      0.61      1000
#        truck       0.62      0.51      0.56      1000
#
#     accuracy                           0.49     10000
#    macro avg       0.52      0.49      0.48     10000
# weighted avg       0.52      0.49      0.48     10000

# %% [markdown]
# We can also use the ```plot_history()``` function available from ```TensorFlow``` to see how our model performs during training.
#
# These plots can tell us *a lot* about whether a model is under- or over-fiting the data. You read more at [this fantastic blog post](https://machinelearningmastery.com/learning-curves-for-diagnosing-machine-learning-model-performance/).
#
# Other useful blogs are [here](https://rstudio-conf-2020.github.io/dl-keras-tf/notebooks/learning-curve-diagnostics.nb.html) and there's a good video overview [here](https://youtu.be/p3CcfIjycBA).

# %%
plot_history(H, 20)

# %% [markdown]
# ## LeNet

# %% [markdown]
# Next, we'll look at a slightly more complicated CNN architecture, known as ```LeNet``` after its creator Yann LeCun, who is now Chief AI Scientist at Meta. You can read more [here](https://en.wikipedia.org/wiki/LeNet).
# >INPUT => CONV => ReLU => MAXPOOL => CONV => ReLU => MAXPOOL => FC => ReLU => FC

# %% [markdown]
# __Define model__

# %%
# define model
model = Sequential()

# first set of layers CONV => RELU => MAXPOOL
model.add(Conv2D(32, (3,3),
                 padding="same",
                 input_shape=(32,32,3)))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size = (2,2),
                       strides = (2,2)))

# second set of layers CONV => RELU => MAXPOOL
model.add(Conv2D(50, (5,5),
                 padding="same"))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size = (2,2),
                       strides = (2,2)))

# FC => RELU
model.add(Flatten())
model.add(Dense(128))
model.add(Activation("relu"))

# softmax classifier
model.add(Dense(10))
model.add(Activation("softmax"))

# %% [markdown]
# __Compile model__

# %%
sgd = SGD(learning_rate=0.01)
model.compile(loss="categorical_crossentropy",
              optimizer=sgd,
              metrics=["accuracy"])
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.SGD` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.SGD`.

# %% [markdown]
# __Model summary__

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 32, 32, 32)        896
#
#  activation_7 (Activation)   (None, 32, 32, 32)        0
#
#  max_pooling2d_2 (MaxPoolin  (None, 16, 16, 32)        0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 16, 16, 50)        40050
#
#  activation_8 (Activation)   (None, 16, 16, 50)        0
#
#  max_pooling2d_3 (MaxPoolin  (None, 8, 8, 50)          0
#  g2D)
#
#  flatten_2 (Flatten)         (None, 3200)              0
#
#  dense_4 (Dense)             (None, 128)               409728
#
#  activation_9 (Activation)   (None, 128)               0
#
#  dense_5 (Dense)             (None, 10)                1290
#
#  activation_10 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 451964 (1.72 MB)
# Trainable params: 451964 (1.72 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# __Train model__

# %%
# train model
H = model.fit(X_train, y_train,
              validation_split=0.1, 
              batch_size=32,
              epochs=20,
              verbose=1)
# Out:
# Epoch 1/20
# 1407/1407 [==============================] - 19s 14ms/step - loss: 1.9143 - accuracy: 0.3113 - val_loss: 1.7368 - val_accuracy: 0.3608
# Epoch 2/20
# 1407/1407 [==============================] - 19s 13ms/step - loss: 1.5213 - accuracy: 0.4566 - val_loss: 1.6306 - val_accuracy: 0.4108
# Epoch 3/20
# 1407/1407 [==============================] - 19s 13ms/step - loss: 1.3628 - accuracy: 0.5168 - val_loss: 1.3550 - val_accuracy: 0.5188
# Epoch 4/20
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.2596 - accuracy: 0.5562 - val_loss: 1.5990 - val_accuracy: 0.4388
# Epoch 5/20
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.1667 - accuracy: 0.5888 - val_loss: 1.2419 - val_accuracy: 0.5630
# Epoch 6/20
# 1407/1407 [==============================] - 17s 12ms/step - loss: 1.0879 - accuracy: 0.6207 - val_loss: 1.2892 - val_accuracy: 0.5488
# Epoch 7/20
# 1407/1407 [==============================] - 17s 12ms/step - loss: 1.0227 - accuracy: 0.6417 - val_loss: 1.0713 - val_accuracy: 0.6304
# Epoch 8/20
# 1407/1407 [==============================] - 17s 12ms/step - loss: 0.9638 - accuracy: 0.6625 - val_loss: 1.0223 - val_accuracy: 0.6478
# Epoch 9/20
# 1407/1407 [==============================] - 17s 12ms/step - loss: 0.9157 - accuracy: 0.6803 - val_loss: 1.0918 - val_accuracy: 0.6282
# Epoch 10/20
# 1407/1407 [==============================] - 17s 12ms/step - loss: 0.8652 - accuracy: 0.6992 - val_loss: 1.0369 - val_accuracy: 0.6422
# Epoch 11/20
# 1407/1407 [==============================] - 17s 12ms/step - loss: 0.8212 - accuracy: 0.7152 - val_loss: 1.0260 - val_accuracy: 0.6448
# Epoch 12/20
# 1407/1407 [==============================] - 18s 12ms/step - loss: 0.7768 - accuracy: 0.7295 - val_loss: 0.9759 - val_accuracy: 0.6612
# Epoch 13/20
# 1407/1407 [==============================] - 18s 12ms/step - loss: 0.7384 - accuracy: 0.7426 - val_loss: 1.0172 - val_accuracy: 0.6560
# Epoch 14/20
# 1407/1407 [==============================] - 18s 12ms/step - loss: 0.6973 - accuracy: 0.7583 - val_loss: 1.0328 - val_accuracy: 0.6642
# Epoch 15/20
# 1407/1407 [==============================] - 17s 12ms/step - loss: 0.6604 - accuracy: 0.7705 - val_loss: 0.9395 - val_accuracy: 0.6784
# Epoch 16/20
# 1407/1407 [==============================] - 17s 12ms/step - loss: 0.6217 - accuracy: 0.7844 - val_loss: 0.9975 - val_accuracy: 0.6644
# Epoch 17/20
# 1407/1407 [==============================] - 17s 12ms/step - loss: 0.5855 - accuracy: 0.7973 - val_loss: 0.9451 - val_accuracy: 0.6896
# Epoch 18/20
# 1407/1407 [==============================] - 18s 12ms/step - loss: 0.5482 - accuracy: 0.8102 - val_loss: 0.9608 - val_accuracy: 0.6858
# Epoch 19/20
# 1407/1407 [==============================] - 18s 12ms/step - loss: 0.5131 - accuracy: 0.8222 - val_loss: 0.9653 - val_accuracy: 0.6934
# Epoch 20/20
# 1407/1407 [==============================] - 17s 12ms/step - loss: 0.4806 - accuracy: 0.8340 - val_loss: 1.1441 - val_accuracy: 0.6550

# %%
plot_history(H,20)

# %%
predictions = model.predict(X_test, batch_size=32)
print(classification_report(y_test.argmax(axis=1),
                            predictions.argmax(axis=1),
                            target_names=label_names))
# Out:
# 313/313 [==============================] - 1s 4ms/step
#               precision    recall  f1-score   support
#
#     airplane       0.63      0.64      0.64      1000
#   automobile       0.74      0.77      0.76      1000
#         bird       0.63      0.50      0.56      1000
#          cat       0.58      0.38      0.46      1000
#         deer       0.75      0.45      0.56      1000
#          dog       0.57      0.60      0.59      1000
#         frog       0.63      0.84      0.72      1000
#        horse       0.76      0.74      0.75      1000
#         ship       0.48      0.95      0.64      1000
#        truck       0.87      0.48      0.62      1000
#
#     accuracy                           0.64     10000
#    macro avg       0.66      0.64      0.63     10000
# weighted avg       0.66      0.64      0.63     10000
